# %%
from fetch_extensions import fetch_vscode_extensions, save_to_json

search_terms = ["devops"]   
max_results = 50   
json_file_path = "../data/extensions_data.json"

extensions_data = fetch_vscode_extensions(search_terms, max_results)
save_to_json(extensions_data, json_file_path)
# Out:
# Data successfully saved to ../data/extensions_data.json

# %%
import requests
import json

def get_extension_info_raw(publisher, extension_name):
    """
    Obtiene el JSON crudo de una extensión del Visual Studio Marketplace.

    Args:
        publisher (str): Nombre del publicador de la extensión.
        extension_name (str): Nombre de la extensión.

    Returns:
        dict: JSON completo de la respuesta.
    """
    url = "https://marketplace.visualstudio.com/_apis/public/gallery/extensionquery"
    headers = {
        "Content-Type": "application/json",
        "Accept": "application/json;api-version=6.1-preview.1"
    }
    payload = {
        "filters": [
            {
                "criteria": [
                    {
                        "filterType": 7,
                        "value": f"{publisher}.{extension_name}"
                    }
                ]
            }
        ],
        "flags": 914  # Ajusta este valor si necesitas más detalles
    }
    
    try:
        response = requests.post(url, headers=headers, json=payload)
        response.raise_for_status()  # Verifica errores HTTP
        data = response.json()
        
        # Imprimir el JSON completo de la respuesta
        print(json.dumps(data, indent=4))
        return data
    except requests.RequestException as e:
        print(f"Error en la solicitud: {e}")
        return {"error": str(e)}
    except Exception as e:
        print(f"Error inesperado: {e}")
        return {"error": str(e)}

# Ejemplo de uso
get_extension_info_raw("RocketSoftware", "rdo-vsc-ibmi")
# Out:
# {
#     "results": [
#         {
#             "extensions": [
#                 {
#                     "publisher": {
#                         "publisherId": "7c1c19cd-78eb-4dfb-8999-99caf7679002",
#                         "publisherName": "GitHub",
#                         "displayName": "GitHub",
#                         "flags": "verified",
#                         "domain": "https://github.com",
#                         "isDomainVerified": true
#                     },
#                     "extensionId": "7ec7d6e6-b89e-4cc5-a59b-d6c4d238246f",
#                     "extensionName": "copilot-chat",
#                     "displayName": "GitHub Copilot Chat",
#                     "flags": "validated, public, trial",
#                     "lastUpdated": "2024-11-26T04:27:09.08Z",
#                     "publishedDate": "2023-04-27T07:13:54.017Z",
#                     "releaseDate": "2023-04-27T07:13:54.017Z",
#                     "shortDescription": "AI chat features powered by Copilot",
#                     "versions": [
#                         {
#                             "version": "0.23.2024112601",
#                             "flags": "validated",
#                             "lastUpdated": "2024-11-26T04:27:09.077Z",
#                             "files": [
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Code.Manifest",
#                                     "source": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Code.Manifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Changelog",
#                                     "source": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Content.Changelog"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Details",
#                                     "source": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Content.Details"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.License",
#                                     "source": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Content.License"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Default",
#                                     "source": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Icons.Default"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Small",
#                                     "source": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Icons.Small"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixManifest",
#                                     "source": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.VsixManifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VSIXPackage",
#                                     "source": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.VSIXPackage"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixSignature",
#                                     "source": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.VsixSignature"
#                                 }
#                             ],
#                             "properties": [
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Getstarted",
#                                     "value": "https://github.com/microsoft/vscode-copilot-release.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Support",
#                                     "value": "https://aka.ms/microsoft/vscode-copilot-release"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Learn",
#                                     "value": "https://github.com/features/copilot?editor=vscode"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Source",
#                                     "value": "https://github.com/microsoft/vscode-copilot-release.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.GitHub",
#                                     "value": "https://github.com/microsoft/vscode-copilot-release.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.Engine",
#                                     "value": "^1.96.0-20241122"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.GitHubFlavoredMarkdown",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionDependencies",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.CustomerQnALink",
#                                     "value": "https://github.com/github-community/community/discussions/categories/copilot"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionPack",
#                                     "value": "GitHub.copilot"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.LocalizedLanguages",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionKind",
#                                     "value": "workspace"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.PreRelease",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Content.Pricing",
#                                     "value": "Trial"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.EnabledApiProposals",
#                                     "value": "extensionsAny,newSymbolNamesProvider,interactive,codeActionAI,activeComment,commentReveal,contribCommentThreadAdditionalMenu,contribCommentsViewThreadMenus,documentFiltersExclusive,embeddings,findTextInFiles,findFiles2@2,textSearchProvider,terminalDataWriteEvent,terminalExecuteCommandEvent,terminalSelection,terminalQuickFixProvider,mappedEditsProvider,aiRelatedInformation,chatParticipantAdditions,chatEditing,defaultChatParticipant@2,chatVariableResolver,contribSourceControlInputBoxMenu,authLearnMore,testObserver,aiTextSearchProvider@2,chatParticipantPrivate@2,chatProvider,contribDebugCreateConfiguration,inlineEdit,textSearchProvider2"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExecutesCode",
#                                     "value": "true"
#                                 }
#                             ],
#                             "assetUri": "https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133",
#                             "fallbackAssetUri": "https://github.gallery.vsassets.io/_apis/public/gallery/publisher/GitHub/extension/copilot-chat/0.23.2024112601/assetbyname"
#                         }
#                     ],
#                     "statistics": [
#                         {
#                             "statisticName": "install",
#                             "value": 17176149.0
#                         },
#                         {
#                             "statisticName": "averagerating",
#                             "value": 2.945122003555298
#                         },
#                         {
#                             "statisticName": "ratingcount",
#                             "value": 164.0
#                         },
#                         {
#                             "statisticName": "trendingdaily",
#                             "value": 0.0052523938660443475
#                         },
#                         {
#                             "statisticName": "trendingmonthly",
#                             "value": 6.848665594478123
#                         },
#                         {
#                             "statisticName": "trendingweekly",
#                             "value": 1.318174780509922
#                         },
#                         {
#                             "statisticName": "updateCount",
#                             "value": 87961146.0
#                         },
#                         {
#                             "statisticName": "weightedRating",
#                             "value": 3.0289198613572506
#                         },
#                         {
#                             "statisticName": "downloadCount",
#                             "value": 120591.0
#                         }
#                     ],
#                     "deploymentType": 0
#                 }
#             ],
#             "pagingToken": null,
#             "resultMetadata": [
#                 {
#                     "metadataType": "ResultCount",
#                     "metadataItems": [
#                         {
#                             "name": "TotalCount",
#                             "count": 1
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }
# {'results': [{'extensions': [{'publisher': {'publisherId': '7c1c19cd-78eb-4dfb-8999-99caf7679002',
#       'publisherName': 'GitHub',
#       'displayName': 'GitHub',
#       'flags': 'verified',
#       'domain': 'https://github.com',
#       'isDomainVerified': True},
#      'extensionId': '7ec7d6e6-b89e-4cc5-a59b-d6c4d238246f',
#      'extensionName': 'copilot-chat',
#      'displayName': 'GitHub Copilot Chat',
#      'flags': 'validated, public, trial',
#      'lastUpdated': '2024-11-26T04:27:09.08Z',
#      'publishedDate': '2023-04-27T07:13:54.017Z',
#      'releaseDate': '2023-04-27T07:13:54.017Z',
#      'shortDescription': 'AI chat features powered by Copilot',
#      'versions': [{'version': '0.23.2024112601',
#        'flags': 'validated',
#        'lastUpdated': '2024-11-26T04:27:09.077Z',
#        'files': [{'assetType': 'Microsoft.VisualStudio.Code.Manifest',
#          'source': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Code.Manifest'},
#         {'assetType': 'Microsoft.VisualStudio.Services.Content.Changelog',
#          'source': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Content.Changelog'},
#         {'assetType': 'Microsoft.VisualStudio.Services.Content.Details',
#          'source': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Content.Details'},
#         {'assetType': 'Microsoft.VisualStudio.Services.Content.License',
#          'source': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Content.License'},
#         {'assetType': 'Microsoft.VisualStudio.Services.Icons.Default',
#          'source': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Icons.Default'},
#         {'assetType': 'Microsoft.VisualStudio.Services.Icons.Small',
#          'source': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.Icons.Small'},
#         {'assetType': 'Microsoft.VisualStudio.Services.VsixManifest',
#          'source': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.VsixManifest'},
#         {'assetType': 'Microsoft.VisualStudio.Services.VSIXPackage',
#          'source': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.VSIXPackage'},
#         {'assetType': 'Microsoft.VisualStudio.Services.VsixSignature',
#          'source': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133/Microsoft.VisualStudio.Services.VsixSignature'}],
#        'properties': [{'key': 'Microsoft.VisualStudio.Services.Links.Getstarted',
#          'value': 'https://github.com/microsoft/vscode-copilot-release.git'},
#         {'key': 'Microsoft.VisualStudio.Services.Links.Support',
#          'value': 'https://aka.ms/microsoft/vscode-copilot-release'},
#         {'key': 'Microsoft.VisualStudio.Services.Links.Learn',
#          'value': 'https://github.com/features/copilot?editor=vscode'},
#         {'key': 'Microsoft.VisualStudio.Services.Links.Source',
#          'value': 'https://github.com/microsoft/vscode-copilot-release.git'},
#         {'key': 'Microsoft.VisualStudio.Services.Links.GitHub',
#          'value': 'https://github.com/microsoft/vscode-copilot-release.git'},
#         {'key': 'Microsoft.VisualStudio.Code.Engine',
#          'value': '^1.96.0-20241122'},
#         {'key': 'Microsoft.VisualStudio.Services.GitHubFlavoredMarkdown',
#          'value': 'true'},
#         {'key': 'Microsoft.VisualStudio.Code.ExtensionDependencies',
#          'value': ''},
#         {'key': 'Microsoft.VisualStudio.Services.CustomerQnALink',
#          'value': 'https://github.com/github-community/community/discussions/categories/copilot'},
#         {'key': 'Microsoft.VisualStudio.Code.ExtensionPack',
#          'value': 'GitHub.copilot'},
#         {'key': 'Microsoft.VisualStudio.Code.LocalizedLanguages', 'value': ''},
#         {'key': 'Microsoft.VisualStudio.Code.ExtensionKind',
#          'value': 'workspace'},
#         {'key': 'Microsoft.VisualStudio.Code.PreRelease', 'value': 'true'},
#         {'key': 'Microsoft.VisualStudio.Services.Content.Pricing',
#          'value': 'Trial'},
#         {'key': 'Microsoft.VisualStudio.Code.EnabledApiProposals',
#          'value': 'extensionsAny,newSymbolNamesProvider,interactive,codeActionAI,activeComment,commentReveal,contribCommentThreadAdditionalMenu,contribCommentsViewThreadMenus,documentFiltersExclusive,embeddings,findTextInFiles,findFiles2@2,textSearchProvider,terminalDataWriteEvent,terminalExecuteCommandEvent,terminalSelection,terminalQuickFixProvider,mappedEditsProvider,aiRelatedInformation,chatParticipantAdditions,chatEditing,defaultChatParticipant@2,chatVariableResolver,contribSourceControlInputBoxMenu,authLearnMore,testObserver,aiTextSearchProvider@2,chatParticipantPrivate@2,chatProvider,contribDebugCreateConfiguration,inlineEdit,textSearchProvider2'},
#         {'key': 'Microsoft.VisualStudio.Code.ExecutesCode', 'value': 'true'}],
#        'assetUri': 'https://github.gallerycdn.vsassets.io/extensions/github/copilot-chat/0.23.2024112601/1732594986133',
#        'fallbackAssetUri': 'https://github.gallery.vsassets.io/_apis/public/gallery/publisher/GitHub/extension/copilot-chat/0.23.2024112601/assetbyname'}],
#      'statistics': [{'statisticName': 'install', 'value': 17176149.0},
#       {'statisticName': 'averagerating', 'value': 2.945122003555298},
#       {'statisticName': 'ratingcount', 'value': 164.0},
#       {'statisticName': 'trendingdaily', 'value': 0.0052523938660443475},
#       {'statisticName': 'trendingmonthly', 'value': 6.848665594478123},
#       {'statisticName': 'trendingweekly', 'value': 1.318174780509922},
#       {'statisticName': 'updateCount', 'value': 87961146.0},
#       {'statisticName': 'weightedRating', 'value': 3.0289198613572506},
#       {'statisticName': 'downloadCount', 'value': 120591.0}],
#      'deploymentType': 0}],
#    'pagingToken': None,
#    'resultMetadata': [{'metadataType': 'ResultCount',
#      'metadataItems': [{'name': 'TotalCount', 'count': 1}]}]}]}

# %%
import requests
import json
import os

def get_extension_info_raw(publisher, extension_name):
    """
    Obtiene el JSON crudo de una extensión del Visual Studio Marketplace.

    Args:
        publisher (str): Nombre del publicador de la extensión.
        extension_name (str): Nombre de la extensión.

    Returns:
        dict: JSON completo de la respuesta.
    """
    url = "https://marketplace.visualstudio.com/_apis/public/gallery/extensionquery"
    headers = {
        "Content-Type": "application/json",
        "Accept": "application/json;api-version=6.1-preview.1"
    }
    payload = {
        "filters": [
            {
                "criteria": [
                    {
                        "filterType": 7,
                        "value": f"{publisher}.{extension_name}"
                    }
                ]
            }
        ],
        "flags": 914  # Ajusta este valor si necesitas más detalles
    }
    
    try:
        response = requests.post(url, headers=headers, json=payload)
        response.raise_for_status()  # Verifica errores HTTP
        data = response.json()
        
        # Imprimir el JSON completo de la respuesta
        print(json.dumps(data, indent=4))
        return data
    except requests.RequestException as e:
        print(f"Error en la solicitud: {e}")
        return {"error": str(e)}
    except Exception as e:
        print(f"Error inesperado: {e}")
        return {"error": str(e)}

def process_extensions(json_file_path):
    """
    Procesa un archivo JSON con información de extensiones y obtiene información adicional de cada una.

    Args:
        json_file_path (str): Ruta al archivo JSON.
    """
    output_dir = "../files"  # Directorio donde se guardarán los archivos de salida

    # Crear el directorio si no existe
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    try:
        # Leer el archivo JSON
        with open(json_file_path, "r", encoding="utf-8") as file:
            extensions = json.load(file)
        
        # Procesar cada extensión
        for extension in extensions:
            publisher = extension["publisher_name"]
            extension_name = extension["ext_name"]
            print(f"Procesando {publisher}.{extension_name}...")
            extension_info = get_extension_info_raw(publisher, extension_name)
            
            # Guardar o procesar la información obtenida
            output_filename = os.path.join(output_dir, f"{publisher}_{extension_name}_info.json")
            with open(output_filename, "w", encoding="utf-8") as output_file:
                json.dump(extension_info, output_file, indent=4, ensure_ascii=False)
            print(f"Información guardada en {output_filename}")
    
    except FileNotFoundError:
        print("El archivo JSON no se encontró.")
    except json.JSONDecodeError:
        print("El archivo JSON tiene un formato inválido.")
    except Exception as e:
        print(f"Error inesperado: {e}")

# Uso del script
process_extensions("/Users/pavt/Documents/research/research-projects/vscode_extensions_vulnerabilities/vscode_vulnerabilities/data/extensions_data.json")
# Out:
# Procesando stateful.runme...
# {
#     "results": [
#         {
#             "extensions": [
#                 {
#                     "publisher": {
#                         "publisherId": "e01ecf81-8aec-4229-a7c4-570a9fa31ca5",
#                         "publisherName": "stateful",
#                         "displayName": "stateful",
#                         "flags": "verified",
#                         "domain": null,
#                         "isDomainVerified": false
#                     },
#                     "extensionId": "4f5bd896-f651-4050-b28c-5cd241921b4e",
#                     "extensionName": "runme",
#                     "displayName": "Runme Notebooks for DevOps",
#                     "flags": "validated, public",
#                     "lastUpdated": "2024-11-27T00:50:41.76Z",
#                     "publishedDate": "2022-10-06T19:48:40.257Z",
#                     "releaseDate": "2022-10-06T19:48:40.257Z",
#                     "shortDescription": "Notebooks for DevOps written in Markdown. Runnable, configurable commands/code and embedded terminals. Integrated with cloud consoles, containers and pipelines.",
#                     "versions": [
#                         {
#                             "version": "3.10.1732642955",
#                             "targetPlatform": "win32-x64",
#                             "flags": "validated",
#                             "lastUpdated": "2024-11-26T17:48:33.463Z",
#                             "files": [
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Code.Manifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715/Microsoft.VisualStudio.Code.Manifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Changelog",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715/Microsoft.VisualStudio.Services.Content.Changelog"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Details",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715/Microsoft.VisualStudio.Services.Content.Details"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.License",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715/Microsoft.VisualStudio.Services.Content.License"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Default",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715/Microsoft.VisualStudio.Services.Icons.Default"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Small",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715/Microsoft.VisualStudio.Services.Icons.Small"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixManifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715/Microsoft.VisualStudio.Services.VsixManifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VSIXPackage",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715/Microsoft.VisualStudio.Services.VSIXPackage"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixSignature",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715/Microsoft.VisualStudio.Services.VsixSignature"
#                                 }
#                             ],
#                             "properties": [
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Color",
#                                     "value": "#0D003D"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Theme",
#                                     "value": "dark"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Getstarted",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Support",
#                                     "value": "https://github.com/stateful/vscode-runme/issues"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Learn",
#                                     "value": "https://runme.dev"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Source",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.GitHub",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.Engine",
#                                     "value": "^1.78.0"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.GitHubFlavoredMarkdown",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionDependencies",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionPack",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.LocalizedLanguages",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionKind",
#                                     "value": "workspace"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.PreRelease",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Content.Pricing",
#                                     "value": "Free"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.EnabledApiProposals",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExecutesCode",
#                                     "value": "true"
#                                 }
#                             ],
#                             "assetUri": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643040715",
#                             "fallbackAssetUri": "https://stateful.gallery.vsassets.io/_apis/public/gallery/publisher/stateful/extension/runme/3.10.1732642955/assetbyname"
#                         },
#                         {
#                             "version": "3.10.1732642955",
#                             "targetPlatform": "linux-x64",
#                             "flags": "validated",
#                             "lastUpdated": "2024-11-26T17:48:27.09Z",
#                             "files": [
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Code.Manifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616/Microsoft.VisualStudio.Code.Manifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Changelog",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616/Microsoft.VisualStudio.Services.Content.Changelog"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Details",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616/Microsoft.VisualStudio.Services.Content.Details"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.License",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616/Microsoft.VisualStudio.Services.Content.License"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Default",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616/Microsoft.VisualStudio.Services.Icons.Default"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Small",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616/Microsoft.VisualStudio.Services.Icons.Small"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixManifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616/Microsoft.VisualStudio.Services.VsixManifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VSIXPackage",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616/Microsoft.VisualStudio.Services.VSIXPackage"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixSignature",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616/Microsoft.VisualStudio.Services.VsixSignature"
#                                 }
#                             ],
#                             "properties": [
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Color",
#                                     "value": "#0D003D"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Theme",
#                                     "value": "dark"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Getstarted",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Support",
#                                     "value": "https://github.com/stateful/vscode-runme/issues"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Learn",
#                                     "value": "https://runme.dev"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Source",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.GitHub",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.Engine",
#                                     "value": "^1.78.0"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.GitHubFlavoredMarkdown",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionDependencies",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionPack",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.LocalizedLanguages",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionKind",
#                                     "value": "workspace"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.PreRelease",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Content.Pricing",
#                                     "value": "Free"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.EnabledApiProposals",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExecutesCode",
#                                     "value": "true"
#                                 }
#                             ],
#                             "assetUri": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643025616",
#                             "fallbackAssetUri": "https://stateful.gallery.vsassets.io/_apis/public/gallery/publisher/stateful/extension/runme/3.10.1732642955/assetbyname"
#                         },
#                         {
#                             "version": "3.10.1732642955",
#                             "targetPlatform": "darwin-arm64",
#                             "flags": "validated",
#                             "lastUpdated": "2024-11-26T17:48:00.1Z",
#                             "files": [
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Code.Manifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209/Microsoft.VisualStudio.Code.Manifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Changelog",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209/Microsoft.VisualStudio.Services.Content.Changelog"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Details",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209/Microsoft.VisualStudio.Services.Content.Details"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.License",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209/Microsoft.VisualStudio.Services.Content.License"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Default",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209/Microsoft.VisualStudio.Services.Icons.Default"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Small",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209/Microsoft.VisualStudio.Services.Icons.Small"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixManifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209/Microsoft.VisualStudio.Services.VsixManifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VSIXPackage",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209/Microsoft.VisualStudio.Services.VSIXPackage"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixSignature",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209/Microsoft.VisualStudio.Services.VsixSignature"
#                                 }
#                             ],
#                             "properties": [
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Color",
#                                     "value": "#0D003D"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Theme",
#                                     "value": "dark"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Getstarted",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Support",
#                                     "value": "https://github.com/stateful/vscode-runme/issues"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Learn",
#                                     "value": "https://runme.dev"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Source",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.GitHub",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.Engine",
#                                     "value": "^1.78.0"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.GitHubFlavoredMarkdown",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionDependencies",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionPack",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.LocalizedLanguages",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionKind",
#                                     "value": "workspace"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.PreRelease",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Content.Pricing",
#                                     "value": "Free"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.EnabledApiProposals",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExecutesCode",
#                                     "value": "true"
#                                 }
#                             ],
#                             "assetUri": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643037209",
#                             "fallbackAssetUri": "https://stateful.gallery.vsassets.io/_apis/public/gallery/publisher/stateful/extension/runme/3.10.1732642955/assetbyname"
#                         },
#                         {
#                             "version": "3.10.1732642955",
#                             "targetPlatform": "win32-arm64",
#                             "flags": "validated",
#                             "lastUpdated": "2024-11-26T17:47:56.877Z",
#                             "files": [
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Code.Manifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981/Microsoft.VisualStudio.Code.Manifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Changelog",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981/Microsoft.VisualStudio.Services.Content.Changelog"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Details",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981/Microsoft.VisualStudio.Services.Content.Details"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.License",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981/Microsoft.VisualStudio.Services.Content.License"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Default",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981/Microsoft.VisualStudio.Services.Icons.Default"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Small",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981/Microsoft.VisualStudio.Services.Icons.Small"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixManifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981/Microsoft.VisualStudio.Services.VsixManifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VSIXPackage",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981/Microsoft.VisualStudio.Services.VSIXPackage"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixSignature",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981/Microsoft.VisualStudio.Services.VsixSignature"
#                                 }
#                             ],
#                             "properties": [
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Color",
#                                     "value": "#0D003D"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Theme",
#                                     "value": "dark"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Getstarted",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Support",
#                                     "value": "https://github.com/stateful/vscode-runme/issues"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Learn",
#                                     "value": "https://runme.dev"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Source",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.GitHub",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.Engine",
#                                     "value": "^1.78.0"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.GitHubFlavoredMarkdown",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionDependencies",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionPack",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.LocalizedLanguages",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionKind",
#                                     "value": "workspace"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.PreRelease",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Content.Pricing",
#                                     "value": "Free"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.EnabledApiProposals",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExecutesCode",
#                                     "value": "true"
#                                 }
#                             ],
#                             "assetUri": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643044981",
#                             "fallbackAssetUri": "https://stateful.gallery.vsassets.io/_apis/public/gallery/publisher/stateful/extension/runme/3.10.1732642955/assetbyname"
#                         },
#                         {
#                             "version": "3.10.1732642955",
#                             "targetPlatform": "darwin-x64",
#                             "flags": "validated",
#                             "lastUpdated": "2024-11-26T17:47:49.37Z",
#                             "files": [
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Code.Manifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353/Microsoft.VisualStudio.Code.Manifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Changelog",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353/Microsoft.VisualStudio.Services.Content.Changelog"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Details",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353/Microsoft.VisualStudio.Services.Content.Details"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.License",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353/Microsoft.VisualStudio.Services.Content.License"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Default",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353/Microsoft.VisualStudio.Services.Icons.Default"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Small",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353/Microsoft.VisualStudio.Services.Icons.Small"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixManifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353/Microsoft.VisualStudio.Services.VsixManifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VSIXPackage",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353/Microsoft.VisualStudio.Services.VSIXPackage"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixSignature",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353/Microsoft.VisualStudio.Services.VsixSignature"
#                                 }
#                             ],
#                             "properties": [
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Color",
#                                     "value": "#0D003D"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Theme",
#                                     "value": "dark"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Getstarted",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Support",
#                                     "value": "https://github.com/stateful/vscode-runme/issues"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Learn",
#                                     "value": "https://runme.dev"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Source",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.GitHub",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.Engine",
#                                     "value": "^1.78.0"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.GitHubFlavoredMarkdown",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionDependencies",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionPack",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.LocalizedLanguages",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionKind",
#                                     "value": "workspace"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.PreRelease",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Content.Pricing",
#                                     "value": "Free"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.EnabledApiProposals",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExecutesCode",
#                                     "value": "true"
#                                 }
#                             ],
#                             "assetUri": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643033353",
#                             "fallbackAssetUri": "https://stateful.gallery.vsassets.io/_apis/public/gallery/publisher/stateful/extension/runme/3.10.1732642955/assetbyname"
#                         },
#                         {
#                             "version": "3.10.1732642955",
#                             "targetPlatform": "linux-arm64",
#                             "flags": "validated",
#                             "lastUpdated": "2024-11-26T17:47:42.83Z",
#                             "files": [
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Code.Manifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542/Microsoft.VisualStudio.Code.Manifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Changelog",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542/Microsoft.VisualStudio.Services.Content.Changelog"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Details",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542/Microsoft.VisualStudio.Services.Content.Details"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.License",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542/Microsoft.VisualStudio.Services.Content.License"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Default",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542/Microsoft.VisualStudio.Services.Icons.Default"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Small",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542/Microsoft.VisualStudio.Services.Icons.Small"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixManifest",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542/Microsoft.VisualStudio.Services.VsixManifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VSIXPackage",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542/Microsoft.VisualStudio.Services.VSIXPackage"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixSignature",
#                                     "source": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542/Microsoft.VisualStudio.Services.VsixSignature"
#                                 }
#                             ],
#                             "properties": [
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Color",
#                                     "value": "#0D003D"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Theme",
#                                     "value": "dark"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Getstarted",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Support",
#                                     "value": "https://github.com/stateful/vscode-runme/issues"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Learn",
#                                     "value": "https://runme.dev"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.Source",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Links.GitHub",
#                                     "value": "https://github.com/stateful/vscode-runme.git"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.Engine",
#                                     "value": "^1.78.0"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.GitHubFlavoredMarkdown",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionDependencies",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionPack",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.LocalizedLanguages",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExtensionKind",
#                                     "value": "workspace"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.PreRelease",
#                                     "value": "true"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Content.Pricing",
#                                     "value": "Free"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.EnabledApiProposals",
#                                     "value": ""
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Code.ExecutesCode",
#                                     "value": "true"
#                                 }
#                             ],
#                             "assetUri": "https://stateful.gallerycdn.vsassets.io/extensions/stateful/runme/3.10.1732642955/1732643029542",
#                             "fallbackAssetUri": "https://stateful.gallery.vsassets.io/_apis/public/gallery/publisher/stateful/extension/runme/3.10.1732642955/assetbyname"
#                         },
#                         {
#                             "version": "0.6.1677525338",
#                             "flags": "validated",
#                             "lastUpdated": "2023-02-27T19:19:18.297Z",
#                             "files": [
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Code.Manifest",
# ...
#                 }
#             ],
#             "pagingToken": null,
#             "resultMetadata": [
#                 {
#                     "metadataType": "ResultCount",
#                     "metadataItems": [
#                         {
#                             "name": "TotalCount",
#                             "count": 1
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }
# Información guardada en ../files/ms_vss-vstsuser_info.json
# Procesando EnterpriseServicesDevOpsTeam.DashBoardMigration...
# {
#     "results": [
#         {
#             "extensions": [
#                 {
#                     "publisher": {
#                         "publisherId": "321635a5-0655-4919-a574-26e1c36c1695",
#                         "publisherName": "EnterpriseServicesDevOpsTeam",
#                         "displayName": "Microsoft DevLabs",
#                         "flags": "verified",
#                         "domain": null,
#                         "isDomainVerified": false
#                     },
#                     "extensionId": "d128eeb7-9db0-4d82-ac63-01e5f1ece97c",
#                     "extensionName": "DashBoardMigration",
#                     "displayName": "Azure DevOps Dashboard Migration",
#                     "flags": "validated, public",
#                     "lastUpdated": "2021-03-02T10:36:44.96Z",
#                     "publishedDate": "2021-01-19T13:38:16.307Z",
#                     "releaseDate": "2021-01-19T13:38:16.307Z",
#                     "shortDescription": "This extension helps you to migrate dashboards across Azure DevOps Projects.",
#                     "versions": [
#                         {
#                             "version": "1.3.202103021",
#                             "flags": "validated",
#                             "lastUpdated": "2021-03-02T10:36:44.96Z",
#                             "files": [
#                                 {
#                                     "assetType": "content/bootstrap-treefy.css",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/content/bootstrap-treefy.css"
#                                 },
#                                 {
#                                     "assetType": "content/bootstrap-treeview.css",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/content/bootstrap-treeview.css"
#                                 },
#                                 {
#                                     "assetType": "content/bootstrap.min.css",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/content/bootstrap.min.css"
#                                 },
#                                 {
#                                     "assetType": "content/c3.min.css",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/content/c3.min.css"
#                                 },
#                                 {
#                                     "assetType": "content/font-awesome.min.css",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/content/font-awesome.min.css"
#                                 },
#                                 {
#                                     "assetType": "content/jquerysctipttop.css",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/content/jquerysctipttop.css"
#                                 },
#                                 {
#                                     "assetType": "content/widget.css",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/content/widget.css"
#                                 },
#                                 {
#                                     "assetType": "DashboardMigrate.html",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/DashboardMigrate.html"
#                                 },
#                                 {
#                                     "assetType": "images/AzureOverview.png",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/AzureOverview.png"
#                                 },
#                                 {
#                                     "assetType": "images/DashboardMigrator.PNG",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/DashboardMigrator.PNG"
#                                 },
#                                 {
#                                     "assetType": "images/FAQTeamArea.png",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/FAQTeamArea.png"
#                                 },
#                                 {
#                                     "assetType": "images/FetchDashboards.PNG",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/FetchDashboards.PNG"
#                                 },
#                                 {
#                                     "assetType": "images/headerImage.png",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/headerImage.png"
#                                 },
#                                 {
#                                     "assetType": "images/logo.png",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/logo.png"
#                                 },
#                                 {
#                                     "assetType": "images/MigrateDashboards.PNG",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/MigrateDashboards.PNG"
#                                 },
#                                 {
#                                     "assetType": "images/PAT.PNG",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/PAT.PNG"
#                                 },
#                                 {
#                                     "assetType": "images/prg3.gif",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/prg3.gif"
#                                 },
#                                 {
#                                     "assetType": "images/VS_logo.png",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/images/VS_logo.png"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Content.Details",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/Microsoft.VisualStudio.Services.Content.Details"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Default",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/Microsoft.VisualStudio.Services.Icons.Default"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Icons.Small",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/Microsoft.VisualStudio.Services.Icons.Small"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.Manifest",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/Microsoft.VisualStudio.Services.Manifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VsixManifest",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/Microsoft.VisualStudio.Services.VsixManifest"
#                                 },
#                                 {
#                                     "assetType": "Microsoft.VisualStudio.Services.VSIXPackage",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/Microsoft.VisualStudio.Services.VSIXPackage"
#                                 },
#                                 {
#                                     "assetType": "scripts/bootstrap-treeview.js",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/scripts/bootstrap-treeview.js"
#                                 },
#                                 {
#                                     "assetType": "scripts/jquery.min.js",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/scripts/jquery.min.js"
#                                 },
#                                 {
#                                     "assetType": "scripts/Migrate.js",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/scripts/Migrate.js"
#                                 },
#                                 {
#                                     "assetType": "sdk/scripts/VSS.SDK.js",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/sdk/scripts/VSS.SDK.js"
#                                 },
#                                 {
#                                     "assetType": "sdk/scripts/VSS.SDK.min.js",
#                                     "source": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536/sdk/scripts/VSS.SDK.min.js"
#                                 }
#                             ],
#                             "properties": [
#                                 {
#                                     "key": "RegistrationId",
#                                     "value": "76927688-bcd5-475a-8c5e-6aa1a57065b6"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Hex",
#                                     "value": "#A8E4A0"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Name",
#                                     "value": "Granny Smith Apple"
#                                 },
#                                 {
#                                     "key": "Microsoft.VisualStudio.Services.Branding.Rgb",
#                                     "value": "(168, 228, 160)"
#                                 }
#                             ],
#                             "assetUri": "https://enterpriseservicesdevopsteam.gallerycdn.vsassets.io/extensions/enterpriseservicesdevopsteam/dashboardmigration/1.3.202103021/1614681266536",
#                             "fallbackAssetUri": "https://enterpriseservicesdevopsteam.gallery.vsassets.io/_apis/public/gallery/publisher/EnterpriseServicesDevOpsTeam/extension/DashBoardMigration/1.3.202103021/assetbyname"
#                         }
#                     ],
#                     "statistics": [
#                         {
#                             "statisticName": "install",
#                             "value": 2679.0
#                         },
#                         {
#                             "statisticName": "averagerating",
#                             "value": 2.5
#                         },
#                         {
#                             "statisticName": "ratingcount",
#                             "value": 4.0
#                         },
#                         {
#                             "statisticName": "trendingdaily",
#                             "value": 0.0
#                         },
#                         {
#                             "statisticName": "trendingmonthly",
#                             "value": 2.0164301717699775
#                         },
#                         {
#                             "statisticName": "trendingweekly",
#                             "value": 0.2613890963405527
#                         },
#                         {
#                             "statisticName": "onpremDownloads",
#                             "value": 549.0
#                         },
#                         {
#                             "statisticName": "weightedRating",
#                             "value": 3.3746478873239436
#                         }
#                     ],
#                     "deploymentType": 0
#                 }
#             ],
#             "pagingToken": null,
#             "resultMetadata": [
#                 {
#                     "metadataType": "ResultCount",
#                     "metadataItems": [
#                         {
#                             "name": "TotalCount",
#                             "count": 1
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }
# Información guardada en ../files/EnterpriseServicesDevOpsTeam_DashBoardMigration_info.json
